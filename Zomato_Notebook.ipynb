# %%
# Importing pandas and numpy Libraries 
import pandas as pd
import numpy as np

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

# %%
# Working on Zomato Dataset
data = pd.read_csv('/home/nineleaps/Downloads/NineLeaps/Zomato_Dataset.csv',index_col = 'RestaurantID')
data.shape
# Out:
# (9551, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9551 entries, 6317637 to 5927402
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   RestaurantName        9551 non-null   object
#  1   CountryCode           9551 non-null   int64
#  2   City                  9551 non-null   object
#  3   Address               9551 non-null   object
#  4   Locality              9551 non-null   object
#  5   LocalityVerbose       9551 non-null   object
#  6   Cuisines              9542 non-null   object
#  7   Currency              9551 non-null   object
#  8   Has_Table_booking     9551 non-null   object
#  9   Has_Online_delivery   9551 non-null   object
#  10  Is_delivering_now     9551 non-null   object
#  11  Switch_to_order_menu  9551 non-null   object
#  12  Price_range           9551 non-null   int64
#  13  Votes                 9551 non-null   int64
#  14  Average_Cost_for_two  9551 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['RestaurantName', 'CountryCode', 'City', 'Address', 'Locality',
#        'LocalityVerbose', 'Cuisines', 'Currency', 'Has_Table_booking',
#        'Has_Online_delivery', 'Is_delivering_now', 'Switch_to_order_menu',
#        'Price_range', 'Votes', 'Average_Cost_for_two', 'Rating'],
#       dtype='object')

# %%
data.describe()
# Out:
#        CountryCode  Price_range         Votes  Average_Cost_for_two  \
# count  9551.000000  9551.000000   9551.000000           9551.000000
# mean     18.365616     1.804837    156.909748           1199.210763
# std      56.750546     0.905609    430.169145          16121.183073
# min       1.000000     1.000000      0.000000              0.000000
# 25%       1.000000     1.000000      5.000000            250.000000
# 50%       1.000000     2.000000     31.000000            400.000000
# 75%       1.000000     2.000000    131.000000            700.000000
# max     216.000000     4.000000  10934.000000         800000.000000
#
#             Rating
# count  9551.000000
# mean      2.891268
# std       1.128845
# min       1.000000
# 25%       2.500000
# 50%       3.200000
# 75%       3.700000
# max       4.900000

# %%
data['RestaurantName'].nunique()
# Out:
# 7446

# %%
print(data['RestaurantName'].unique())
# Out:
# ['Le Petit Souffle' 'Izakaya Kikufuji' 'Heat - Edsa Shangri-La' ...
#  'Huqqa' 'A??k Kahve' "Walter's Coffee Roastery"]

# %%
data['Currency'].unique()
# Out:
# array(['Botswana Pula(P)', 'Brazilian Real(R$)', 'Dollar($)',
#        'Emirati Diram(AED)', 'Indian Rupees(Rs.)',
#        'Indonesian Rupiah(IDR)', 'NewZealand($)', 'Pounds(?)',
#        'Qatari Rial(QR)', 'Rand(R)', 'Sri Lankan Rupee(LKR)',
#        'Turkish Lira(TL)'], dtype=object)

# %%
df = data

# %%
df.head()
# Out:
#                       RestaurantName  CountryCode              City  \
# RestaurantID
# 6317637             Le Petit Souffle          162       Makati City
# 6304287             Izakaya Kikufuji          162       Makati City
# 6300002       Heat - Edsa Shangri-La          162  Mandaluyong City
# 6318506                         Ooma          162  Mandaluyong City
# 6314302                  Sambo Kojin          162  Mandaluyong City
#
#                                                         Address  \
# RestaurantID
# 6317637       Third Floor| Century City Mall| Kalayaan Avenu...
# 6304287       Little Tokyo| 2277 Chino Roces Avenue| Legaspi...
# 6300002       Edsa Shangri-La| 1 Garden Way| Ortigas| Mandal...
# 6318506       Third Floor| Mega Fashion Hall| SM Megamall| O...
# 6314302       Third Floor| Mega Atrium| SM Megamall| Ortigas...
#
#                                                 Locality  \
# RestaurantID
# 6317637        Century City Mall| Poblacion| Makati City
# ...

# %%
df.tail()
# Out:
#                         RestaurantName  CountryCode      City  \
# RestaurantID
# 5915730                    Naml? Gurme          208  ?stanbul
# 5908749                    Ceviz A?ac?          208  ?stanbul
# 5915807                          Huqqa          208  ?stanbul
# 5916112                     A??k Kahve          208  ?stanbul
# 5927402       Walter's Coffee Roastery          208  ?stanbul
#
#                                                         Address   Locality  \
# RestaurantID
# 5915730       Kemanke? Karamustafa Pa?a Mahallesi| R?ht?m Ca...    Karak?y
# 5908749       Ko?uyolu Mahallesi| Muhittin ?st?nda? Caddesi|...   Ko?uyolu
# 5915807       Kuru?e?me Mahallesi| Muallim Naci Caddesi| No ...  Kuru?e?me
# 5916112       Kuru?e?me Mahallesi| Muallim Naci Caddesi| No ...  Kuru?e?me
# 5927402       Cafea?a Mahallesi| Bademalt? Sokak| No 21/B| K...       Moda
#
#                   LocalityVerbose                         Cuisines  \
# RestaurantID
# ...

# %%
df.head(2)
# Out:
#                 RestaurantName  CountryCode         City  \
# RestaurantID
# 6317637       Le Petit Souffle          162  Makati City
# 6304287       Izakaya Kikufuji          162  Makati City
#
#                                                         Address  \
# RestaurantID
# 6317637       Third Floor| Century City Mall| Kalayaan Avenu...
# 6304287       Little Tokyo| 2277 Chino Roces Avenue| Legaspi...
#
#                                                 Locality  \
# RestaurantID
# 6317637        Century City Mall| Poblacion| Makati City
# 6304287       Little Tokyo| Legaspi Village| Makati City
#
#                                                 LocalityVerbose  \
# RestaurantID
# 6317637       Century City Mall| Poblacion| Makati City| Mak...
# 6304287       Little Tokyo| Legaspi Village| Makati City| Ma...
#
#                                 Cuisines          Currency Has_Table_booking  \
# RestaurantID
# ...

# %%
a = df['Average_Cost_for_two'].sum()
print(a)
# Out:
# 11453662

# %%
a = []

for item in data['City']:
    if "?" in item:
        a.append(item)
print(pd.Series(a).unique())
# Out:
# ['Bras?lia' 'S?o Paulo' '?stanbul']

# %%
fix_map = {
    "Bras?lia": "Brasília",
    "S?o Paulo": "São Paulo",
    "?stanbul": "İstanbul"
}

df["City"] = df["City"].replace(fix_map)

# %%
df["City"].unique()
# Out:
# array(['Makati City', 'Mandaluyong City', 'Pasay City', 'Pasig City',
#        'Quezon City', 'San Juan City', 'Santa Rosa', 'Tagaytay City',
#        'Taguig City', 'Brasília', 'Rio de Janeiro', 'São Paulo', 'Albany',
#        'Armidale', 'Athens', 'Augusta', 'Balingup', 'Beechworth', 'Boise',
#        'Cedar Rapids/Iowa City', 'Chatham-Kent', 'Clatskanie', 'Cochrane',
#        'Columbus', 'Consort', 'Dalton', 'Davenport', 'Des Moines',
#        'Dicky Beach', 'Dubuque', 'East Ballina', 'Fernley', 'Flaxton',
#        'Forrest', 'Gainesville', 'Hepburn Springs', 'Huskisson',
#        'Inverloch', 'Lakes Entrance', 'Lakeview', 'Lincoln', 'Lorn',
#        'Macedon', 'Macon', 'Mayfield', 'Mc Millan', 'Middleton Beach',
#        'Miller', 'Monroe', 'Montville', 'Ojo Caliente', 'Orlando',
#        'Palm Cove', 'Paynesville', 'Penola', 'Pensacola',
#        'Phillip Island', 'Pocatello', 'Potrero', 'Princeton',
#        'Rest of Hawaii', 'Savannah', 'Singapore', 'Sioux City',
# ...

# %%
df.columns
# Out:
# Index(['RestaurantName', 'CountryCode', 'City', 'Address', 'Locality',
#        'LocalityVerbose', 'Cuisines', 'Currency', 'Has_Table_booking',
#        'Has_Online_delivery', 'Is_delivering_now', 'Switch_to_order_menu',
#        'Price_range', 'Votes', 'Average_Cost_for_two', 'Rating'],
#       dtype='object')

# %%
df.Rating.unique()
# Out:
# array([4.8, 4.5, 4.4, 4.9, 4. , 4.2, 4.3, 3.6, 4.7, 3. , 3.8, 3.7, 3.2,
#        3.1, 1. , 4.1, 3.3, 4.6, 3.9, 3.4, 3.5, 2.2, 2.9, 2.4, 2.6, 2.8,
#        2.1, 2.7, 2.5, 1.8, 2. , 2.3, 1.9])

# %%
print(df["Locality"].unique())
# Out:
# ['Century City Mall| Poblacion| Makati City'
#  'Little Tokyo| Legaspi Village| Makati City'
#  'Edsa Shangri-La| Ortigas| Mandaluyong City' ... 'Ko?uyolu' 'Kuru?e?me'
#  'Moda']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9551 entries, 6317637 to 5927402
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   RestaurantName        9551 non-null   object
#  1   CountryCode           9551 non-null   int64
#  2   City                  9551 non-null   object
#  3   Address               9551 non-null   object
#  4   Locality              9551 non-null   object
#  5   LocalityVerbose       9551 non-null   object
#  6   Cuisines              9542 non-null   object
#  7   Currency              9551 non-null   object
#  8   Has_Table_booking     9551 non-null   object
#  9   Has_Online_delivery   9551 non-null   object
#  10  Is_delivering_now     9551 non-null   object
#  11  Switch_to_order_menu  9551 non-null   object
#  12  Price_range           9551 non-null   int64
#  13  Votes                 9551 non-null   int64
#  14  Average_Cost_for_two  9551 non-null   int64
# ...

# %%
df.Switch_to_order_menu.unique()
# Out:
# array(['No'], dtype=object)

# %%
df.CountryCode.unique()
# Out:
# array([162,  30, 216,  14,  37, 184, 214,   1,  94, 148, 215, 166, 189,
#        191, 208])

# %%
df["rating_category"] = "Unknown"

df.loc[df["Rating"] <= 2.5, "rating_category"] = "Poor"
df.loc[(df["Rating"] > 2.5) & (df["Rating"] <= 3.5), "rating_category"] = "Average"
df.loc[(df["Rating"] > 3.5) & (df["Rating"] <= 4.5), "rating_category"] = "Good"
df.loc[df["Rating"] > 4.5, "rating_category"] = "Excellent"

# %%
df.columns
# Out:
# Index(['RestaurantName', 'CountryCode', 'City', 'Address', 'Locality',
#        'LocalityVerbose', 'Cuisines', 'Currency', 'Has_Table_booking',
#        'Has_Online_delivery', 'Is_delivering_now', 'Switch_to_order_menu',
#        'Price_range', 'Votes', 'Average_Cost_for_two', 'Rating',
#        'rating_category'],
#       dtype='object')

# %%
df['rating_category'].unique()
# Out:
# array(['Excellent', 'Good', 'Average', 'Poor'], dtype=object)

# %%
# 1. List all restaurants in a specific locality.
locality = "SM Megamall| Ortigas| Mandaluyong City"

result = df[df["Locality"] == locality][["RestaurantName","Rating"]]

print(result)
# Out:
#              RestaurantName  Rating
# RestaurantID
# 6318506                Ooma     4.9
# 6314302         Sambo Kojin     4.8
# 18189371       Din Tai Fung     4.4

# %%
# 2. Show the name and city of restaurants with a rating lower than 3.

df[df['Rating']<3][['RestaurantName','City']]
# Out:
#                             RestaurantName            City
# RestaurantID
# 6600060                      Sandubas Caf?        Brasília
# 7305048              Quiosque Chopp Brahma  Rio de Janeiro
# 6710645                   Cantinho da Gula       São Paulo
# 6701419                       Divino Fog?o       São Paulo
# 6703956                        Super Grill       São Paulo
# ...                                    ...             ...
# 7001208       De Fontein Belgian Beer Cafe        Auckland
# 6900714                   Pepe's Piri Piri      Birmingham
# 18273002            Damascena Coffee House      Birmingham
# 5800634            Elite Indian Restaurant         Colombo
# 5800156                       Queen's Cafe         Colombo
#
# [3581 rows x 2 columns]

# %%
# 3. Count the number of restaurants that do not offer table booking.
a = df[df["Has_Table_booking"]=='No']["RestaurantID"].count()
print(a)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RestaurantID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 2
# ...

# %%
# 4. Display restaurants that have an average cost for two less than $50.
currency_map = {
    "Botswana Pula(P)": "BWP",
    "Brazilian Real(R$)": "BRL",
    "Dollar($)": "USD",
    "Emirati Diram(AED)": "AED",
    "Indian Rupees(Rs.)": "INR",
    "Indonesian Rupiah(IDR)": "IDR",
    "NewZealand($)": "NZD",
    "Pounds(?)": "GBP",
    "Qatari Rial(QR)": "QAR",
    "Rand(R)": "ZAR",
    "Sri Lankan Rupee(LKR)": "LKR",
    "Turkish Lira(TL)": "TRY"
}
df["Currency_Code"] = df["Currency"].map(currency_map)
exchange_to_usd = {
    "USD": 1.00,
    "BWP": 0.079,
    "BRL": 0.19,
    "AED": 0.27,
    "INR": 0.012,
    "IDR": 0.000067,
    "NZD": 0.60,
    "GBP": 1.26,
    "QAR": 0.27,
    "ZAR": 0.054,
    "LKR": 0.0031,
    "TRY": 0.052
}
df["Cost_in_USD"] = df["Average_Cost_for_two"] * df["Currency_Code"].map(exchange_to_usd)
df[df["Cost_in_USD"]<50]["RestaurantName"]
# Out:
# RestaurantID
# 18255654    Hobing Korean Dessert Cafe
# 6600681                    Chez Michou
# 6601005             Caf? Daniel Briand
# 6600292       Casa do Biscoito Mineiro
# 6600441                          Maori
#                        ...
# 5915730                    Naml? Gurme
# 5908749                    Ceviz A?ac?
# 5915807                          Huqqa
# 5916112                     A??k Kahve
# 5927402       Walter's Coffee Roastery
# Name: RestaurantName, Length: 9359, dtype: object

# %%
# 5. Find restaurants with more than 100 votes.
df[df["Votes"]>100]['RestaurantName']
# Out:
# RestaurantID
# 6317637            Le Petit Souffle
# 6304287            Izakaya Kikufuji
# 6300002      Heat - Edsa Shangri-La
# 6318506                        Ooma
# 6314302                 Sambo Kojin
#                      ...
# 5915730                 Naml? Gurme
# 5908749                 Ceviz A?ac?
# 5915807                       Huqqa
# 5916112                  A??k Kahve
# 5927402    Walter's Coffee Roastery
# Name: RestaurantName, Length: 2805, dtype: object

# %%
# 6. List the names of restaurants offering both table booking and online delivery.

df[(df["Has_Table_booking"] == "Yes") & (df["Has_Online_delivery"] == 'Yes')]["RestaurantName"]
# Out:
# RestaurantID
# 5701978                       Pizza Di Rocco
# 5700052     Cho Gao - Crowne Plaza Abu Dhabi
# 5702418                               Gazebo
# 18235425                    Indian By Nature
# 206488                         Maharaja Bhog
#                           ...
# 11371                                Chili's
# 18292672                          Blue Water
# 6507967                      Tales & Spirits
# 6506206              18 Degrees Resto Lounge
# 96814                         Saffron Mantra
# Name: RestaurantName, Length: 435, dtype: object

# %%
# 7. Show the cuisines offered by restaurants in 'Paris'.

paris_cuisines = df.loc[df["City"] == "Paris", "Cuisines"]
print(paris_cuisines)
# Out:
# Series([], Name: Cuisines, dtype: object)

# %%
# 8. Count the number of restaurants in each price range.

df['Price_range'].value_counts()
# Out:
# Price_range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
# 9. Display the top 10 restaurants by rating in a specific country.
CountryCode = "1"

result = (
    df[df["CountryCode"] == CountryCode]
    [["RestaurantName", "Rating"]]
    .sort_values(by="Rating", ascending=False)
    .head(10)
)

print(result)
# Out:
# Empty DataFrame
# Columns: [RestaurantName, Rating]
# Index: []

# %%
# 10. List all restaurants with 'Cafe' in their cuisine type.
result = df[df["Cuisines"].str.contains("Cafe", case=False, na=False)]["RestaurantName"]
print(result)
# Out:
# RestaurantID
# 18185059                 Cafe Arabelle
# 18255654    Hobing Korean Dessert Cafe
# 6308205        Wildflour Cafe + Bakery
# 6601005             Caf? Daniel Briand
# 6600060                  Sandubas Caf?
#                        ...
# 5926979                   Leman K?lt?r
# 5916085                    Dem Karak?y
# 5908749                    Ceviz A?ac?
# 5916112                     A??k Kahve
# 5927402       Walter's Coffee Roastery
# Name: RestaurantName, Length: 707, dtype: object

# %%
avg_votes_locality = df.groupby("Locality")["Votes"].mean().reset_index()
print(avg_votes_locality)
# Out:
#                                  Locality        Votes
# 0     12th Square Building| Banjara Hills  3374.000000
# 1                                 ?ayyolu   126.000000
# 2                            ?guas Claras    15.666667
# 3                                 ?mitk?y   152.000000
# 4                              ?ukurambar   115.000000
# ...                                   ...          ...
# 1203                          Yusuf Sarai    37.240000
# 1204             Z Square Mall| Mall Road    41.000000
# 1205                          Zakir Nagar     0.285714
# 1206                          Zoo Tiniali   238.500000
# 1207             ibis New Delhi| Aerocity     4.500000
#
# [1208 rows x 2 columns]

# %%
online_delivery_city = df[df["Has_Online_delivery"] == "Yes"].groupby("City")["RestaurantName"].count().reset_index()
online_delivery_city.rename(columns={"RestaurantName": "Online_Delivery_Count"}, inplace=True)
print(online_delivery_city)
# Out:
#             City  Online_Delivery_Count
# 0      Abu Dhabi                     11
# 1      Ahmedabad                     11
# 2      Bangalore                      7
# 3     Chandigarh                      6
# 4        Chennai                     13
# 5     Coimbatore                      7
# 6          Dubai                      6
# 7      Faridabad                     35
# 8      Ghaziabad                     10
# 9        Gurgaon                    425
# 10     Hyderabad                      7
# 11        Jaipur                     10
# 12         Kochi                      5
# 13       Kolkata                      8
# 14        Mohali                      1
# 15        Mumbai                      7
# 16        Nagpur                     10
# 17     New Delhi                   1489
# 18         Noida                    364
# 19          Pune                      7
# 20  Secunderabad                      1
# 21       Sharjah                     11

# %%
table_booking_city = df[df["Has_Table_booking"] == "Yes"].groupby("City")["RestaurantName"].count()
table_booking_city = table_booking_city.sort_values(ascending=False).reset_index()
print(table_booking_city.head())
# Out:
#         City  RestaurantName
# 0  New Delhi             715
# 1    Gurgaon             204
# 2      Noida             112
# 3  Faridabad              15
# 4    Chennai              13

# %%
chinese_rating = df[df["Cuisines"].str.contains("Chinese", na=False)]
avg_chinese_rating = chinese_rating["Rating"].mean()
print(avg_chinese_rating)
# Out:
# 2.821844127332602

# %%
most_common_price_london = df[df["City"] == "London"]["Price_range"].mode()[0]
print(most_common_price_london)
# Out:
# 3

# %%
# Split cuisines by comma and explode
df_cuisines = df.copy()
df_cuisines["CuisineList"] = df_cuisines["Cuisines"].str.split(",")
df_exploded = df_cuisines.explode("CuisineList")

cuisine_count_country = df_exploded.groupby("CountryCode")["CuisineList"].nunique().reset_index()
cuisine_count_country.rename(columns={"CuisineList": "Total_Cuisines"}, inplace=True)
print(cuisine_count_country)
# Out:
#     CountryCode  Total_Cuisines
# 0             1            1392
# 1            14              21
# 2            30              42
# 3            37               4
# 4            94              18
# 5           148              28
# 6           162              19
# 7           166              14
# 8           184              19
# 9           189              56
# 10          191              20
# 11          208              23
# 12          214              46
# 13          215              57
# 14          216             229

# %%
min_cost_city = df.loc[df.groupby("City")["Average_Cost_for_two"].idxmin()][["City", "RestaurantName", "Average_Cost_for_two"]]
print(min_cost_city)
# Out:
#                          City                            RestaurantName  \
# RestaurantID
# 5704118             Abu Dhabi                             Tikka Tonight
# 3400073                  Agra               The Latitude - Radisson Blu
# 18396250            Ahmedabad                             Huber & Holly
# 17284105               Albany                             Cookie Shoppe
# 18317988            Allahabad                            The BrewMaster
# ...                       ...                                       ...
# 17694056              Weirton  Theo Yianni's Authentic Greek Restaurant
# 7101011       Wellington City                              Ekim Burgers
# 17559793       Winchester Bay                 Fishpatrick's Crabby Cafe
# 16668008              Yorkton                             Arigato Sushi
# 5901782              İstanbul                                 Starbucks
#
#               Average_Cost_for_two
# RestaurantID
# 5704118                         50
# ...

# %%
top_localities = df["Locality"].value_counts().head(5).reset_index()
top_localities.columns = ["Locality", "Restaurant_Count"]
print(top_localities)
# Out:
#           Locality  Restaurant_Count
# 0  Connaught Place               122
# 1   Rajouri Garden                99
# 2         Shahdara                87
# 3   Defence Colony                86
# 4    Malviya Nagar                85

# %%
delivery_percentage = df.groupby("City")["Is_delivering_now"].value_counts(normalize=True).mul(100).rename("percentage").reset_index()

# Filter only delivering now
delivery_percentage = delivery_percentage[delivery_percentage["Is_delivering_now"] == "Yes"]
print(delivery_percentage[["City", "percentage"]])
# Out:
#           City  percentage
# 25  Chandigarh    5.555556
# 52     Gurgaon    1.073345
# 91   New Delhi    0.292344
# 93       Noida    0.462963

# %%
locality = "YourLocalityName"

price_dist_locality = df[df["Locality"] == locality]["Price_range"].value_counts().reset_index()
price_dist_locality.columns = ["Price_range", "Count"]
print(price_dist_locality)
# Out:
# Empty DataFrame
# Columns: [Price_range, Count]
# Index: []
